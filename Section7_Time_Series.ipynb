# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import datetime 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=yf.download('NG=F', start='2024-04-01', end='2024-04-13')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df.head(10)
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2024-04-01  1.755  1.853  1.706  1.837      1.837  169145
# 2024-04-02  1.837  1.881  1.778  1.862      1.862  170434
# 2024-04-03  1.852  1.906  1.836  1.841      1.841  133034
# 2024-04-04  1.844  1.853  1.769  1.774      1.774  179437
# 2024-04-05  1.779  1.823  1.755  1.785      1.785  191179
# 2024-04-08  1.770  1.850  1.746  1.844      1.844  216676
# 2024-04-09  1.847  1.924  1.838  1.872      1.872  215016
# 2024-04-10  1.888  1.943  1.867  1.885      1.885  174388
# 2024-04-11  1.874  1.892  1.754  1.764      1.764  230318
# 2024-04-12  1.767  1.785  1.731  1.770      1.770  230318

# %%
type(df.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.index = pd.to_datetime(df.index)

# %%
df
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2024-04-01  1.755  1.853  1.706  1.837      1.837  169145
# 2024-04-02  1.837  1.881  1.778  1.862      1.862  170434
# 2024-04-03  1.852  1.906  1.836  1.841      1.841  133034
# 2024-04-04  1.844  1.853  1.769  1.774      1.774  179437
# 2024-04-05  1.779  1.823  1.755  1.785      1.785  191179
# 2024-04-08  1.770  1.850  1.746  1.844      1.844  216676
# 2024-04-09  1.847  1.924  1.838  1.872      1.872  215016
# 2024-04-10  1.888  1.943  1.867  1.885      1.885  174388
# 2024-04-11  1.874  1.892  1.754  1.764      1.764  230318
# 2024-04-12  1.767  1.785  1.731  1.770      1.770  230318

# %%
type(df.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df = pd.read_csv("Materials/ETH_1H.csv")
df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.set_index("Date",inplace=True)

# %%
df
# Out:
#                   Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...         ...
# 2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
df.index = pd.to_datetime(df.index)
# Out:
# C:\Users\OKej\AppData\Local\Temp\ipykernel_21880\3150677299.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.index = pd.to_datetime(df.index)
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.index = pd.to_datetime(df.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1121, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1119         result = _convert_and_box_cache(arg, cache_array, name=arg.name)
#    1120     else:
# -> 1121         result = convert_listlike(arg, format, name=arg.name)
#    1122 elif is_list_like(arg):
#    1123     try:
# ...

# %%
df.index = pd.to_datetime(df.index, format = '%Y-%m-%d %I-%p')

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
jan1 =  pd.to_datetime('2022, 1, 1')
jan1.day_name()
# Out:
# 'Saturday'

# %%
df.index.max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df.index.min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
timePeriod= df.index.max() - df.index.min()
timePeriod
# Out:
# Timedelta('986 days 09:00:00')

# %%
df.loc['2017-07-01']
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2017-07-01 23:00:00  ETHUSD  263.84  264.97  260.31  263.12  1902503.11
# 2017-07-01 22:00:00  ETHUSD  257.13  264.36  256.03  263.84  1290127.76
# 2017-07-01 21:00:00  ETHUSD  258.17  260.56  254.15  257.13  2765560.88
# 2017-07-01 20:00:00  ETHUSD  258.49  262.00  257.12  258.17  2366698.50
# 2017-07-01 19:00:00  ETHUSD  259.50  260.88  253.23  258.49  3962669.00
# 2017-07-01 18:00:00  ETHUSD  263.51  266.73  255.27  259.50  5396852.35
# 2017-07-01 17:00:00  ETHUSD  268.00  268.44  262.39  263.51  1894983.33
# 2017-07-01 16:00:00  ETHUSD  272.57  272.57  267.60  268.00  1287300.75
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# ...

# %%
df=yf.download('NG=F', start='2024-04-01', end='2024-04-13')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df.loc['2024-04-01':'2024-04-05']
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2024-04-01  1.755  1.853  1.706  1.837      1.837  169145
# 2024-04-02  1.837  1.881  1.778  1.862      1.862  170434
# 2024-04-03  1.852  1.906  1.836  1.841      1.841  133034
# 2024-04-04  1.844  1.853  1.769  1.774      1.774  179437
# 2024-04-05  1.779  1.823  1.755  1.785      1.785  191179

# %%
df.loc['2024-04']
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2024-04-01  1.755  1.853  1.706  1.837      1.837  169145
# 2024-04-02  1.837  1.881  1.778  1.862      1.862  170434
# 2024-04-03  1.852  1.906  1.836  1.841      1.841  133034
# 2024-04-04  1.844  1.853  1.769  1.774      1.774  179437
# 2024-04-05  1.779  1.823  1.755  1.785      1.785  191179
# 2024-04-08  1.770  1.850  1.746  1.844      1.844  216676
# 2024-04-09  1.847  1.924  1.838  1.872      1.872  215016
# 2024-04-10  1.888  1.943  1.867  1.885      1.885  174388
# 2024-04-11  1.874  1.892  1.754  1.764      1.764  230318
# 2024-04-12  1.767  1.785  1.731  1.770      1.770  230318

# %%
df=yf.download('NG=F', start='2024-01-01', end='2024-04-13')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
plt.figure(figsize=(15,5))
plt.title('Natgas stock Prices 2024')
plt.xlabel("Year")
plt.ylabel("Price")
plt.plot(df['Adj Close'])

# %%
plt.figure(figsize=(15,5))
plt.title('Apple Stock Prices for 5 years')
plt.xlabel('Year')
plt.plot(df.loc['2024']['Adj Close'])
